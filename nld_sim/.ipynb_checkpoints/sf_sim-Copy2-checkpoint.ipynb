# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Set random seed for reproducibility
np.random.seed(1)

# %%
# Parameters
N = 100  # number of nodes
alpha = 1.0  # decay rate
beta = 1.0  # interaction strength
dt = 0.01  # time step
steps = 20000  # total steps

# %%
# Using Barabási-Albert model which creates networks with gamma ≈ 3
m = 2 # number of edges to attach from a new node to existing nodes
G = nx.barabasi_albert_graph(N, m)
A = nx.adjacency_matrix(G).toarray()

# Initialize state vector x
x = np.zeros(N)

# Set last 10 nodes to random values between 0 and 0.1
x[90:] = np.random.uniform(0, 1, 10) /10
x[90] = x[90]*10

# Store history for plotting
x_history = np.zeros((steps + 1, N))
x_history[0] = x

# %%
# Simulation using Euler method
def simulate_step(x, A, alpha, beta, dt):
    # Calculate sum of Aij*xj for each i
    interaction_term = np.dot(A, x)
    
    # Calculate dx/dt for each node
    dxdt = -alpha * x + beta * (1 - x) * interaction_term
    
    # Euler step
    x_new = x + dt * dxdt
    
    # Ensure values stay in [0, 1]
    x_new = np.clip(x_new, 0, 1)
    
    return x_new

# %%
# Run simulation
for t in range(steps):
    x = simulate_step(x, A, alpha, beta, dt)
    x_history[t + 1] = x

# %%
# Create time array
time = np.arange(0, (steps + 1) * dt, dt)

# %%
# Plotting
plt.figure(figsize=(15, 10))

# Plot for nodes 1, 15, 80
plt.subplot(2,2,1)
plt.semilogx(time, x_history[:, 0], 'b-', label='Node 1')
plt.xlabel('Time (log scale)')
plt.ylabel('State (x)')
plt.title('Time Evolution of Nodes 1')
plt.grid(True)
plt.legend()

plt.subplot(2,2,2)
plt.semilogx(time, x_history[:, 14], 'g-', label='Node 15')
plt.xlabel('Time (log scale)')
plt.ylabel('State (x)')
plt.title('Time Evolution of Nodes 15')
plt.grid(True)
plt.legend()

plt.subplot(2,2,3)
plt.semilogx(time, x_history[:, 79], 'r-', label='Node 80')
plt.xlabel('Time (log scale)')
plt.ylabel('State (x)')
plt.title('Time Evolution of Nodes 80')
plt.grid(True)
plt.legend()

plt.subplot(2,2,4)
plt.semilogx(time, x_history[:, 90], 'c-', label='Node 91')
plt.semilogx(time, x_history[:, 99], 'm-', label='Node 100')
plt.xlabel('Time (log scale)')
plt.ylabel('State (x)')
plt.title('Time Evolution of Nodes 91 and 100')
plt.grid(True)
plt.legend()

plt.tight_layout()

# %% [markdown]
# ### After Perturbation:

# %%
def perturb_simulate_step(x,A,alpha,beta,dt,perturbed_node,fixed_value):
   
    # Calculate sum of Aij*xj for each i
    interaction_term = np.dot(A, x)
    
    # Calculate dx/dt for each node
    dxdt = -alpha * x + beta * (1 - x) * interaction_term
    
    # Euler step
    x_new = x + dt * dxdt
    
    # Ensure values stay in [0, 1]
    x_new = np.clip(x_new, 0, 1)

    x_new[perturbed_node] = fixed_value
    
    return x_new

# %%
# Parameters
max_steps = 20000  # total steps
perturbed_node =  0
perturbation_constant = 0.3

# %%
x_history2 = np.zeros((steps+1,N))
x_history2[0] = x

# print("Before Perturbation",x)
fixed_value = np.clip(x[perturbed_node] + perturbation_constant, 0, 1)
print(x[perturbed_node])
x[perturbed_node] = fixed_value
# print("After Perturbation",x)

print(fixed_value)
# print(x_history2[1])
# Out:
# 0.9226896291264728
# 1.0

# %%
# # Run simulation
# for t in range(steps):
#     x = perturb_simulate_step(x, A, alpha, beta, dt,perturbed_node,fixed_value)
#     x_history2[t + 1] = x

# print(x_history2[2] - x_history2[1])
# print(x_history2[1])

# %%
def check_steady(x1,x2):
    for i in (x1-x2):
        if(abs(i)>1e-10):
            return False
    return True

# %%
time_steady = max_steps

# %%
for t in range(max_steps):
    xcopy = x
    x = perturb_simulate_step(x, A, alpha, beta, dt,perturbed_node,fixed_value)
    if check_steady(xcopy,x):
        time_steady = t
        
    x_history2[t + 1] = x
# print(x_history2[2] - x_history2[1])
# print(x_history2[1])

# %%
time = np.arange(0, (time_steady + 1) * dt, dt)

# %%
# # Plotting
# plt.figure(figsize=(15, 10))

# adj_list =list(G.neighbors(perturbed_node))

# num_plots = len(adj_list)  # Number of nodes to plot
# # Determine number of rows and columns for subplots
# cols = 3  # Adjust this to your desired number of columns
# rows = (num_plots + cols - 1) // cols  # Compute the required number of rows

# fig, axes = plt.subplots(rows, cols, figsize=(15, 5 * rows))  # Dynamically sized grid

# # Flatten axes array if necessary
# axes = axes.flatten()

# # Plot for all nodes in the adjacency list
# for i, node in enumerate(adj_list):
#     axes[i].semilogx(time, x_history2[:, i], 'b-', label=f'Node {node}')
#     axes[i].set_xlabel('Time (log scale)')
#     axes[i].set_ylabel('State (x)')
#     axes[i].set_title(f'Time Evolution of Node {node}')
#     axes[i].grid(True)
#     axes[i].legend()

# # Hide any unused subplots
# for j in range(len(adj_list), len(axes)):
#     axes[j].axis('off')

# plt.tight_layout()

# %%
plt.figure(figsize=(15, 10))

half_life = time_steady / 2
adj_list =list(G.neighbors(perturbed_node))

num_plots = len(adj_list)  # Number of nodes to plot
cols = 3
rows = (num_plots + cols - 1) // cols  # Compute the required number of rows

fig, axes = plt.subplots(rows, cols, figsize=(15, 5 * rows))  # Dynamically sized grid

# Flatten axes array if necessary
axes = axes.flatten()

# Plot for all nodes in the adjacency list
for i, node in enumerate(adj_list):
    axes[i].semilogx(time_steady, x_history2[:, i], 'b-', label=f'Node {node}')
    
    # # Annotate the half-life
    # half_life_index = (np.abs(np.array(time_steady) - half_life)).argmin()  # Find the closest time_steady index to half-life
    # half_life_time = time_steady[half_life_index]
    # half_life_value = x_history2[half_life_index, i]
    # axes[i].annotate(f'$t_{{1/2}}$', 
    #                  xy=(half_life_time, half_life_value), 
    #                  xytext=(half_life_time * 1.2, half_life_value * 1.2), 
    #                  arrowprops=dict(facecolor='red', arrowstyle='->'),
    #                  fontsize=10, color='red')

    axes[i].set_xlabel('Time (log scale)')
    axes[i].set_ylabel('State (x)')
    axes[i].set_title(f'Time Evolution of Node {node}')
    axes[i].grid(True)
    axes[i].legend()

# Hide any unused subplots
for j in range(len(adj_list), len(axes)):
    axes[j].axis('off')

plt.tight_layout()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 17
#      15 # Plot for all nodes in the adjacency list
#      16 for i, node in enumerate(adj_list):
# ---> 17     axes[i].semilogx(time_steady, x_history2[:, i], 'b-', label=f'Node {node}')
#      19     # # Annotate the half-life
#      20     # half_life_index = (np.abs(np.array(time_steady) - half_life)).argmin()  # Find the closest time_steady index to half-life
#      21     # half_life_time = time_steady[half_life_index]
#    (...)
#      26     #                  arrowprops=dict(facecolor='red', arrowstyle='->'),
#      27     #                  fontsize=10, color='red')
#      29     axes[i].set_xlabel('Time (log scale)')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\axes\_axes.py:1912, in Axes.semilogx(self, *args, **kwargs)
#    1908 d = {k: v for k, v in kwargs.items()
#    1909      if k in ['base', 'subs', 'nonpositive',
#    1910               'basex', 'subsx', 'nonposx']}
#    1911 self.set_xscale('log', **d)
# -> 1912 return self.plot(
#    1913     *args, **{k: v for k, v in kwargs.items() if k not in d})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\axes\_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (20001,)
